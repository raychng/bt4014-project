# %%
# Imported required packages
from __future__ import annotations
from abc import ABC, abstractmethod
from typing import List
from tqdm import tqdm

import random
import numpy as np
import pandas as pd
from scipy.stats import beta
import matplotlib.pyplot as plt


# Setting plot size, plot style & random seed
plt.rcParams["figure.figsize"] = (20,10)
plt.style.use('ggplot')
random.seed(1)

# %%
class BanditAlgorithm(ABC):
    """
    Abstract class to capture common behaviours among different types of bandit algorithms.
    
    As much as possible, NumPy operations are used to improve runtime.
    
    select_arm will depend on specific bandit algorithm and is left as an abstract method.
    """
    
    def set_arms(self, n_arms: int) -> BanditAlgorithm:
        """
        Method to set counts & values if previously not initialised
        
        :param n_arms: Number of arms in the simulation
        :return: Self
        """
        self.counts = np.full(n_arms, 0, dtype=int)
        self.values = np.full(n_arms, 0.0)
        return self
    
    @abstractmethod
    def select_arm(self) -> int:
        """
        Method to select arm
        
        :return: Index of chosen arm
        """
        pass
    
    def update(self, chosen_arm: int, reward: float) -> BanditAlgorithm:
        """
        Method to update counts & values after choosing an arm and obtaining a reward
        
        :param chosen_arm: Index of chosen arm
        :param reward: Reward earned from arm
        :return: Self
        """
        # Updating counts
        self.counts[chosen_arm] += 1
        n = self.counts[chosen_arm]
        value = self.values[chosen_arm]
        
        # Updating value
        new_value = (((n - 1) / float(n)) * value) + ((1 / float(n)) * reward)
        self.values[chosen_arm] = new_value
        return self
    
    def __str__(self) -> str:
        # Return name of algorithm, for plotting graphs
        return self.__class__.__name__

# %%
class EpsilonGreedy(BanditAlgorithm):
    """
    Epsilon-Greedy bandit algorithm
    """
    
    def __init__(self, epsilon: float = 0.1) -> None:
        # Default epsilon is 0.1
        self.epsilon = epsilon
        return
    
    def select_arm(self) -> int:
        # Observe if this step will be exploration or exploitation
        if random.random() > self.epsilon:
            # If exploit, select best arm
            return np.argmax(self.values)
        else:
            # If explore, select random arm
            return random.randrange(len(self.values))
    
    def __str__(self) -> str:
        return super().__str__() + f" with epsilon={self.epsilon}"

# %%
class EpsilonDecay(BanditAlgorithm):
    """
    Epsilon-Decay bandit algorithm
    """
    
    def select_arm(self) -> int:
        # Calculate epsilon
        epsilon = 1 / ((sum(self.counts) / len(self.counts)) + 1)
        
        # Observe if this step will be exploration or exploitation
        if random.random() > epsilon:
            # If exploit, select best arm
            return np.argmax(self.values)
        else:
            # If explore, select random arm
            return random.randrange(len(self.values))

# %%
class Softmax(BanditAlgorithm):
    """
    Softmax bandit algorithm
    """
    
    def __init__(self, tau: float = 0.1) -> None:
        # Default temperature is 0.1
        self.tau = tau
        return
    
    def select_arm(self) -> int:
        # Calcualte proability
        exp_vals = np.exp(self.values / self.tau)
        pi = exp_vals / np.sum(exp_vals)
        
        # Draw arm based on probability
        choice = np.random.choice(len(self.values), p=pi)
        return choice
    
    def __str__(self) -> str:
        return super().__str__() + f" with temperature={self.tau}"

# %%
class AnnealingSoftmax(BanditAlgorithm):
    """
    Annealing softmax bandit algorithm
    """
    
    def select_arm(self) -> int:
        # Calculate temperature
        tau = 1 / ((sum(self.counts) / len(self.counts)) + 1)
        
        # Calcualte proability
        exp_vals = np.exp(self.values / tau)
        pi = exp_vals / np.sum(exp_vals)
        
        # Draw arm based on probability
        choice = np.random.choice(len(self.values), p=pi)
        return choice

# %%
class UCB(BanditAlgorithm):
    """
    Upper confidence bound bandit algorithm
    """
    
    def select_arm(self) -> int:
        # Ensure that each arm has been played at least once
        for arm, count in enumerate(self.counts):
            if count == 0:
                return arm     

        total_count = sum(self.counts)
        # Calculate curiousity bonus which allows for exploration
        bonus = np.sqrt(2 * np.log(total_count) / self.counts)
        # Calculate the ucb of each arm
        ucb_values = self.values + bonus
        
        # Return arm with highest ucb
        return np.argmax(ucb_values)

# %%
class BetaBandit(BanditAlgorithm):
    """
    Abstract bandit algorithm class for BayesianUCB & Thompson Sampling, both utilise Beta distribution for prior distribution
    """
    
    def __init__(self
                 , prior_alpha: float = 1.0
                 , prior_beta: float = 1.0
                 ) -> None:
        super().__init__()
        # Default is the use uniform prior
        self.prior_alpha = prior_alpha
        self.prior_beta = prior_beta
        return
    
    def set_arms(self, n_arms: int) -> BanditAlgorithm:
        self.alphas = np.full(n_arms, self.prior_alpha)
        self.betas = np.full(n_arms, self.prior_beta)
        super().set_arms(n_arms)
        return self
    
    def update(self, chosen_arm: int, reward: float) -> BanditAlgorithm:
        # Updating counts & values
        super().update(chosen_arm, reward)
        # Updating alphas & betas
        self.alphas[chosen_arm] += reward
        self.betas[chosen_arm] += (1 - reward)
        return self

# %%
class BayesianUCB(BetaBandit):
    """
    Bayesian upper confidence bound bandit algorithm
    """
    
    def __init__(self
                 , prior_alpha: float = 1.0
                 , prior_beta: float = 1.0
                 , stdnum: float = 3.0
                 ) -> None:
        super().__init__(prior_alpha, prior_beta)
        self.stdnum = stdnum
        return
    
    def select_arm(self) -> int:
        # Calculate the ucb of each arm
        
        # Calculate mean of beta distribution
        expected_rewards = self.alphas / (self.alphas + self.betas)
        # Calculate curiousity bonus which allows for exploration
        bonus = beta.std(self.alphas, self.betas) * self.stdnum
        ucb_values = expected_rewards + bonus
        
        # Return arm with highest ucb
        return np.argmax(ucb_values)
    
    def __str__(self) -> str:
        return super().__str__() + f" with stdnum={self.stdnum}"

# %%
class ThompsonSampling(BetaBandit):
    """
    Thompson sampling bandit algorithm
    """
    
    def select_arm(self) -> int:
        # Calculate theta values for each arm
        theta_values = np.random.beta(self.alphas, self.betas)
        
        # Return arm with highest theta
        return np.argmax(theta_values)

# %%
class ContextualBandit(BanditAlgorithm):
    """
    Abstract class for contextual bandits, select_arm and update methods take an additional input, context.
    """
    
    def set_arms(self, n_arms: int, n_features: int) -> BanditAlgorithm:
        self.n_features = n_features
        
        # A stores covariance matrix of features seen by arm, initialised as identity matrix
        self.A = np.tile(np.eye(n_features), (n_arms, 1, 1))
        # b stores sum of rewards, or 'Y' in the case of a linear model, for each arm
        self.b = np.zeros((n_arms, n_features))
        return self
    
    @abstractmethod
    def select_arm(self, context: np.ndarray) -> int:
        pass
    
    def update(self
               , chosen_arm: int
               , reward: float
               , context: np.ndarray
               ) -> BanditAlgorithm:
        # Updating A and b
        self.A[chosen_arm] += np.outer(context, context)
        self.b[chosen_arm] += reward * context
        return self

# %%
class LinUCB(ContextualBandit):
    """
    Linear UCB contextual bandit algorithm
    """
    
    def __init__(self, alpha: float = 0.1) -> None:
        # alpha will determine level of exploration, default is 0.1
        self.alpha = alpha
        return
    
    def set_arms(self
                 , n_arms: int
                 , n_features: int
                 ) -> BanditAlgorithm:  
        
        super().set_arms(n_arms, n_features)
        
        # theta refers to the regression coefficients, recall OLS solution
        # theta does not change at each call to select_arm, as it does not depend on context, so we can store as attribute to avoid duplicate computations
        self.theta = np.zeros((n_arms, n_features))
        
        return self
    
    def select_arm(self, context: np.ndarray) -> int:
        n_arms = self.A.shape[0]
        p_arms = np.zeros(n_arms)
        
        for arm in range(n_arms):
            # Calculating scores for each arm's linear model, including exploration bonus
            p_arms[arm] = (
                (context @ self.theta[arm]) 
                + (self.alpha * 
                    np.sqrt(context.transpose() 
                            @ np.linalg.inv(self.A[arm])
                            @ context))
            )
        # Return arm with highest score
        return np.argmax(p_arms)
    
    def update(self
               , chosen_arm: int
               , reward: float
               , context: np.ndarray
               ) -> BanditAlgorithm:
        super().update(chosen_arm, reward, context)
        
        # Getting inverse of the covariance matrix of chosen arm's linear model
        A_inv = np.linalg.inv(self.A[chosen_arm])
        # Calculating weight vector for chosen arm's linear model
        self.theta[chosen_arm] = A_inv @ self.b[chosen_arm]
        return self
    
    def __str__(self) -> str:
        return super().__str__() + f" with alpha={self.alpha}"

# %%
class ContextualThompsonSampling(ContextualBandit):
    """
    Contextual Thompson Sampling with linear payoff
    """
    
    def __init__(self
                 , delta: float = 0.5
                 , epsilon: float = 0.5
                 , R: float = 0.01
                 ) -> None:
        # Defaults follow example implementation
        self.delta = delta
        self.epsilon = epsilon
        self.R = R
        return
    
    def set_arms(self, n_arms: int, n_features: int) -> BanditAlgorithm:
        super().set_arms(n_arms, n_features)
        
        # v is fixed, we can store as attribute to avoid duplicate computations
        self.v = self.R * np.sqrt(
                24 / self.epsilon * self.n_features * np.log(1 / self.delta)
            )
        # mu_hat does not change at each call to select_arm, as it does not depend on context, so we can store as attribute to avoid duplicate computations
        self.mu_hat = np.zeros((n_arms, n_features))
        return self
    
    def select_arm(self, context: np.ndarray) -> int:
        n_arms = self.A.shape[0]
        scores = np.zeros(n_arms)
        
        for arm in range(n_arms):
            # Sampling mu_tilde for Gaussian distribution, exploration bonus arises from v
            mu_tilde = np.random.multivariate_normal(
                self.mu_hat[arm], (self.v ** 2) * np.linalg.inv(self.A[arm])
                )
            # Calculating score for each arm
            scores[arm] = context.transpose() @ mu_tilde
        
        # Return arm with highest score
        return np.argmax(scores)
    
    def update(self
               , chosen_arm: int
               , reward: float
               , context: np.ndarray
               ) -> BanditAlgorithm:
        super().update(chosen_arm, reward, context)
        
        # Getting inverse of the covariance matrix of chosen arm
        A_inv = np.linalg.inv(self.A[chosen_arm])
        # Calculating mu_hat for chosen arm
        self.mu_hat[chosen_arm] = A_inv @ self.b[chosen_arm]
        return self
    
    def __str__(self) -> str:
        return super().__str__() + f" with delta={self.delta}, epsilon={self.epsilon}, R={self.R}"

# %%
def evaluation_replay(
    algos: List[BanditAlgorithm]
    , data: pd.DataFrame
    , context_cols: List[str]
    ) -> pd.DataFrame:
    """
    Function to perform evaluation replay with multiple bandit algorithms, including contextual bandits
    
    Results will contain policy, reward, cumulative reward for each time step
    
    :param algos: List of bandit algorithms to run
    :param data: DataFrame with 'business_id' as arm, 'stars' as reward
    :param context_cols: List of column names of the context features
    :return: DataFrame containg results
    """
    # Results will be collected as list of dictionaries
    results = []
    
    # Count number of reviews
    n = data.shape[0]
    # Count number of arms
    n_arms = data['business_id'].nunique()
    # Excluding all non-context columns
    context_df = data[context_cols]
    # Count number of features
    n_features = context_df.shape[1]
    
    # Note that bandit algorithms use arm as indexes, so we need to factorize 'business_id' into integer keys
    arm_id_series, business_id_order = pd.factorize(data['business_id'])
    data['arm_id'] = arm_id_series
    
    # Randomly shuffle data, as original data was in sequence of business_id
    data = data.sample(frac=1).reset_index(drop=True)
    
    for algo in algos:
        # Initialising arms
        if isinstance(algo, ContextualBandit):
            algo.set_arms(n_arms, n_features)
        else:
            algo.set_arms(n_arms)
        
        cumulative_reward = 0.0
        for t in tqdm(range(n), desc=f'Running {str(algo)}'):
            # Extract context at current time step
            context = context_df.iloc[t].to_numpy()
            
            # Draw arm
            if isinstance(algo, ContextualBandit):
                chosen_arm = algo.select_arm(context)
            else:
                chosen_arm = algo.select_arm()
            
            # Compare to actual arm
            actual_arm = data.iloc[t]['arm_id']
            if chosen_arm == actual_arm:
                # Update algorithm with reward if chosen arm matches actual arm
                reward = data.iloc[t]['stars']
                if isinstance(algo, ContextualBandit):
                    algo.update(chosen_arm, reward, context)
                else:
                    algo.update(chosen_arm, reward)
                
                # Updating cumulative reward
                cumulative_reward += reward
                
                # Appending results at current step
                current_step = {
                    'policy': str(algo),
                    'time_step': t,
                    'business_id': data.iloc[t]['business_id'],
                    'reward': reward,
                    'cumulative_reward': cumulative_reward
                }
                results.append(current_step)
    
    results_df = pd.DataFrame(results)
    # Calculating average reward
    results_df['average_reward'] = (
        results_df['cumulative_reward'] / (results_df['time_step'] + 1)
        ).fillna(value=0.0)
    return results_df

# %%
def present_results(data: pd.DataFrame, target_metric: str) -> None:
    """
    Helper function to plot results, x-axis will be time_step
    
    :param data: DataFrame containg results of simulation
    :param target_metric: Metric to plot on y-axis
    """
    fig, ax = plt.subplots()
    # Set of colors for plot labels
    colors = ['b', 'g', 'r', 'c', 'm', 'k', 'yellow', 'darkorange', 'blueviolet', 'lime', 'slategrey', 'hotpink', 'maroon', 'deepskyblue']
    
    # Collect names of algorithm
    algo_names = data['policy'].unique().tolist()
    for i, algo_name in enumerate(algo_names):      
        
        # Filter results for that algorithm
        algo_result = data[data['policy'] == algo_name]
        ax.plot(
            algo_result['time_step']
            , algo_result[target_metric]
            , label=algo_name
            , color=colors[i])
    plt.legend()
    plt.title(f"{target_metric} at each step")

# %%
data = pd.read_csv('toronto_reviews_all_features.csv')
print(data.shape)
data.head()
# Out:
# (15573, 66)
#    Unnamed: 0               review_id                 user_id  \
# 0           0  lsoSqIrrDbQvWpMvsSj2xw  u0LXt3Uea_GidxRW1xcsfg
# 1           1  WYDFJOBOl7cycd7gN-c_xA  u0LXt3Uea_GidxRW1xcsfg
# 2           2  Enuk_DJbK0JPmgbFU8ePKw  u0LXt3Uea_GidxRW1xcsfg
# 3           3  6TPQNYqfragIrimGFKK7_g  AQJauQ3Q8aeEQc9DHzcpXg
# 4           4  YSNO1rTbyCmmuKpgbmCUCQ  G3civyLatxrzYk0lln3MUQ
#
#               business_id  stars        date  \
# 0  RtUvSWO_UZ8V3Wpj0n077w      0  2012-12-03
# 1  zgQHtqX0gqMw1nlBZl2VnQ      0  2012-10-30
# 2  N93EYZy9R0sdlEvubu94ig      0  2012-09-23
# 3  RtUvSWO_UZ8V3Wpj0n077w      1  2017-05-20
# 4  RtUvSWO_UZ8V3Wpj0n077w      1  2017-08-29
#
#                                                 text  \
# 0  Wanted to check out this place due to all the ...
# 1  really excited to hear of this restaurant comi...
# 2  Not sure what the hype is, but decided to give...
# 3  Love this place! If I ever have international ...
# 4  This place can accumulate some line up so come...
#
#                        name                                address  \
# 0  "KINKA IZAKAYA ORIGINAL"                        "398 Church St"
# 1     "Momofuku Noodle Bar"  "190 University Avenue, Ground Floor"
# 2            "Banh Mi Boys"                   "392 Queen Street W"
# 3  "KINKA IZAKAYA ORIGINAL"                        "398 Church St"
# 4  "KINKA IZAKAYA ORIGINAL"                        "398 Church St"
#
#    arm_American  ...  user_Chinese_ratio  user_Desserts_ratio  \
# 0           0.0  ...            0.333333                  0.0
# 1           1.0  ...            0.333333                  0.0
# 2           0.0  ...            0.333333                  0.0
# 3           0.0  ...            0.000000                  0.0
# 4           0.0  ...            0.000000                  0.0
#
#    user_Italian_ratio  user_Japanese_ratio  user_Korean_ratio  \
# 0                 0.0             0.666667           0.333333
# 1                 0.0             0.666667           0.333333
# 2                 0.0             0.666667           0.333333
# 3                 0.0             1.000000           0.000000
# 4                 0.0             0.500000           0.000000
#
#    user_Mexican_ratio  user_Nightlife_ratio  user_Seafood_ratio  \
# 0                0.00              0.333333                0.00
# 1                0.00              0.333333                0.00
# 2                0.00              0.333333                0.00
# 3                0.00              1.000000                0.00
# 4                0.25              0.250000                0.25
#
#    user_Thai_ratio  user_Vietnamese_ratio
# 0             0.00               0.333333
# 1             0.00               0.333333
# 2             0.00               0.333333
# 3             0.00               0.000000
# 4             0.25               0.000000
#
# [5 rows x 66 columns]

# %%
cuisine_cols = [
    'American',
    'Asian Fusion',
    'Bakeries',
    'Bars',
    'Breakfast & Brunch',
    'British',
    'Buffets',
    'Burgers',
    'Cafes',
    'Caterers',
    'Chinese',
    'Desserts',
    'French',
    'Italian',
    'Japanese',
    'Korean',
    'Mexican',
    'Music Venues',
    'Nightlife',
    'Salad',
    'Seafood',
    'Thai',
    'Vietnamese'
]
remove_cols = ['British', 'Buffets', 'Burgers', 'Cafes', 'Caterers', 'French', 'Music Venues', 'Salad']
cuisine_cols = [x for x in cuisine_cols if x not in remove_cols]

neighborhood_cols = ['Downtown Core',
 'Financial District',
 'Queen Street West',
 'Kensington Market',
 'Wychwood',
 'Entertainment District',
 'Parkdale',
 'Ryerson',
 'Distillery District',
 'Liberty Village',]



user_cols = [
    'stars_stddev',
]
relevant_cols = [
    'review_id',
    'user_id',
    'business_id',
    'stars',
    'date',
    'text',
    'name',
    'address'
]

# %%
# Defining subset of features
arm_features = ['arm_' + cuisine for cuisine in cuisine_cols]
ratio_features = ['user_' + cuisine + '_ratio' for cuisine in cuisine_cols]

# %%
# Initialise all the algorithms to run
algos = [
    EpsilonGreedy(epsilon=0.1)
    , EpsilonDecay()
    , Softmax(tau=0.1)
    , AnnealingSoftmax()
    , UCB()
    , BayesianUCB()
    , ThompsonSampling()
    , LinUCB()
    , ContextualThompsonSampling()
]
results = evaluation_replay(algos, data, arm_features + ratio_features + neighborhood_cols + user_cols)
# Out:
# Running EpsilonGreedy with epsilon=0.1: 100%|██████████| 15573/15573 [00:05<00:00, 2830.34it/s]
# Running EpsilonDecay: 100%|██████████| 15573/15573 [00:14<00:00, 1067.14it/s]
# Running Softmax with temperature=0.1: 100%|██████████| 15573/15573 [00:19<00:00, 789.85it/s]
# Running AnnealingSoftmax: 100%|██████████| 15573/15573 [00:20<00:00, 774.97it/s]
# Running UCB: 100%|██████████| 15573/15573 [00:15<00:00, 1018.09it/s]
# Running BayesianUCB with stdnum=3.0: 100%|██████████| 15573/15573 [00:20<00:00, 752.54it/s]
# Running ThompsonSampling: 100%|██████████| 15573/15573 [00:17<00:00, 898.42it/s]
# Running LinUCB with alpha=0.1: 100%|██████████| 15573/15573 [11:41<00:00, 22.21it/s]
# Running ContextualThompsonSampling with delta=0.5, epsilon=0.5, R=0.01: 100%|██████████| 15573/15573 [23:47<00:00, 10.91it/s]

# %%
# Save results as csv
#results.to_csv('results2.csv')
results
# Out:
#                                                  policy  time_step  \
# 0                        EpsilonGreedy with epsilon=0.1          0
# 1                        EpsilonGreedy with epsilon=0.1         75
# 2                        EpsilonGreedy with epsilon=0.1        152
# 3                        EpsilonGreedy with epsilon=0.1        161
# 4                        EpsilonGreedy with epsilon=0.1        203
# ...                                                 ...        ...
# 6491  ContextualThompsonSampling with delta=0.1, eps...      15445
# 6492  ContextualThompsonSampling with delta=0.1, eps...      15481
# 6493  ContextualThompsonSampling with delta=0.1, eps...      15526
# 6494  ContextualThompsonSampling with delta=0.1, eps...      15551
# 6495  ContextualThompsonSampling with delta=0.1, eps...      15564
#
#                  business_id  reward  cumulative_reward  average_reward
# 0     RtUvSWO_UZ8V3Wpj0n077w       1                1.0        1.000000
# 1     RtUvSWO_UZ8V3Wpj0n077w       1                2.0        0.026316
# 2     RtUvSWO_UZ8V3Wpj0n077w       1                3.0        0.019608
# 3     RtUvSWO_UZ8V3Wpj0n077w       1                4.0        0.024691
# 4     RtUvSWO_UZ8V3Wpj0n077w       1                5.0        0.024510
# ...                      ...     ...                ...             ...
# 6491  RtUvSWO_UZ8V3Wpj0n077w       1              438.0        0.028357
# 6492  e41TP5cXZqSrz50xCBJqZw       1              439.0        0.028356
# 6493  k6zmSLmYAquCpJGKNnTgSQ       1              440.0        0.028338
# 6494  aLcFhMe6DDJ430zelCpd2A       1              441.0        0.028356
# 6495  MS-hfug4QDXqb_Mws3qlzA       0              441.0        0.028333
#
# [6496 rows x 6 columns]

# %%
present_results(results[results['average_reward'] < 0.2], 'average_reward')

# %%
present_results(results, 'cumulative_reward')

# %% [markdown]
# Test out with hyperparameters

# %%
algos = [
    EpsilonGreedy(epsilon=0.1)
    , EpsilonGreedy(epsilon=0.3)
    , EpsilonDecay()
    , Softmax(tau=0.1)
    , Softmax(tau=0.3)
    , AnnealingSoftmax()
    , UCB()
    , BayesianUCB()
    , ThompsonSampling()
    , LinUCB()
    , LinUCB(alpha=0.3)
    , ContextualThompsonSampling()
    , ContextualThompsonSampling(delta=0.1, epsilon=0.1)
]
results2 = evaluation_replay(algos, data, arm_features + ratio_features + neighborhood_cols + user_cols)
# Out:
# Running EpsilonGreedy with epsilon=0.1: 100%|██████████| 15573/15573 [00:03<00:00, 4750.01it/s]
# Running EpsilonGreedy with epsilon=0.3: 100%|██████████| 15573/15573 [00:03<00:00, 4321.58it/s]
# Running EpsilonDecay: 100%|██████████| 15573/15573 [00:03<00:00, 4438.45it/s]
# Running Softmax with temperature=0.1: 100%|██████████| 15573/15573 [00:04<00:00, 3419.07it/s]
# Running Softmax with temperature=0.3: 100%|██████████| 15573/15573 [00:04<00:00, 3554.49it/s]
# Running AnnealingSoftmax: 100%|██████████| 15573/15573 [00:04<00:00, 3361.96it/s]
# Running UCB: 100%|██████████| 15573/15573 [00:04<00:00, 3773.22it/s]
# Running BayesianUCB with stdnum=3.0: 100%|██████████| 15573/15573 [00:05<00:00, 3060.66it/s]
# Running ThompsonSampling: 100%|██████████| 15573/15573 [00:04<00:00, 3622.87it/s]
# Running LinUCB with alpha=0.1: 100%|██████████| 15573/15573 [10:47<00:00, 24.05it/s]
# Running LinUCB with alpha=0.3: 100%|██████████| 15573/15573 [20:45<00:00, 12.50it/s]
# Running ContextualThompsonSampling with delta=0.5, epsilon=0.5, R=0.01: 100%|██████████| 15573/15573 [16:56<00:00, 15.32it/s]
# Running ContextualThompsonSampling with delta=0.1, epsilon=0.1, R=0.01: 100%|██████████| 15573/15573 [19:00<00:00, 13.65it/s]

# %%
results2.to_csv('results_toronto_with_params.csv')

# %%
results2 = pd.read_csv('results_toronto_with_params.csv')

# %%
present_results(results2[results2['average_reward'] < 0.2], 'average_reward')

# %%
results2
# Out:
#       Unnamed: 0                                             policy  \
# 0              0                     EpsilonGreedy with epsilon=0.1
# 1              1                     EpsilonGreedy with epsilon=0.1
# 2              2                     EpsilonGreedy with epsilon=0.1
# 3              3                     EpsilonGreedy with epsilon=0.1
# 4              4                     EpsilonGreedy with epsilon=0.1
# ...          ...                                                ...
# 9880        9880  ContextualThompsonSampling with delta=0.1, eps...
# 9881        9881  ContextualThompsonSampling with delta=0.1, eps...
# 9882        9882  ContextualThompsonSampling with delta=0.1, eps...
# 9883        9883  ContextualThompsonSampling with delta=0.1, eps...
# 9884        9884  ContextualThompsonSampling with delta=0.1, eps...
#
#       time_step             business_id  reward  cumulative_reward  \
# 0            20  RtUvSWO_UZ8V3Wpj0n077w       0                0.0
# 1            21  RtUvSWO_UZ8V3Wpj0n077w       1                1.0
# 2            27  RtUvSWO_UZ8V3Wpj0n077w       1                2.0
# 3            31  RtUvSWO_UZ8V3Wpj0n077w       1                3.0
# 4            32  RtUvSWO_UZ8V3Wpj0n077w       1                4.0
# ...         ...                     ...     ...                ...
# 9880      15411  iGEvDk6hsizigmXhDKs2Vg       1              468.0
# 9881      15486  RwRNR4z3kY-4OsFqigY5sw       1              469.0
# 9882      15489  Yl2TN9c23ZGLUBSD9ks5Uw       1              470.0
# 9883      15515  mZRKH9ngRY92bI_irrHq6w       1              471.0
# 9884      15564  h_4dPV9M9aYaBliH1Eoeeg       1              472.0
#
#       average_reward
# 0           0.000000
# 1           0.045455
# 2           0.071429
# 3           0.093750
# 4           0.121212
# ...              ...
# 9880        0.030366
# 9881        0.030283
# 9882        0.030342
# 9883        0.030356
# 9884        0.030324
#
# [9885 rows x 7 columns]

# %%
present_results(results2, 'cumulative_reward')

# %%
results2.policy.unique()
# Out:
# array(['EpsilonGreedy with epsilon=0.1', 'EpsilonGreedy with epsilon=0.3',
#        'EpsilonDecay', 'Softmax with temperature=0.1',
#        'Softmax with temperature=0.3', 'AnnealingSoftmax', 'UCB',
#        'BayesianUCB with stdnum=3.0', 'ThompsonSampling',
#        'LinUCB with alpha=0.1', 'LinUCB with alpha=0.3',
#        'ContextualThompsonSampling with delta=0.5, epsilon=0.5, R=0.01',
#        'ContextualThompsonSampling with delta=0.1, epsilon=0.1, R=0.01'],
#       dtype=object)

# %%
present_results(results2[(results2['policy'] == 'ContextualThompsonSampling with delta=0.5, epsilon=0.5, R=0.01') | 
                         (results2['policy'] == 'ContextualThompsonSampling with delta=0.1, epsilon=0.1, R=0.01')], 'cumulative_reward')

# %%
present_results(results2[(results2['policy'] == 'EpsilonGreedy with epsilon=0.1') | 
                         (results2['policy'] == 'EpsilonGreedy with epsilon=0.3')], 'cumulative_reward')

# %%
present_results(results2[(results2['policy'] == 'LinUCB with alpha=0.3') | 
                         (results2['policy'] == 'LinUCB with alpha=0.1')], 'cumulative_reward')

# %%
results2.to_csv('results_toronto_with_params.csv')

# %% [markdown]
# Increasing size of data using sampling with replacement, to make it the same size as Las Vegas Dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15573 entries, 0 to 15572
# Data columns (total 66 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     15573 non-null  int64
#  1   review_id                      15573 non-null  object
#  2   user_id                        15573 non-null  object
#  3   business_id                    15573 non-null  object
#  4   stars                          15573 non-null  int64
#  5   date                           15573 non-null  object
#  6   text                           15573 non-null  object
#  7   name                           15573 non-null  object
#  8   address                        15573 non-null  object
#  9   arm_American                   15573 non-null  float64
#  10  arm_Asian Fusion               15573 non-null  float64
#  11  arm_Bakeries                   15573 non-null  float64
#  12  arm_Bars                       15573 non-null  float64
#  13  arm_Breakfast & Brunch         15573 non-null  float64
#  14  arm_Chinese                    15573 non-null  float64
#  15  arm_Desserts                   15573 non-null  float64
#  16  arm_Italian                    15573 non-null  float64
#  17  arm_Japanese                   15573 non-null  float64
#  18  arm_Korean                     15573 non-null  float64
#  19  arm_Mexican                    15573 non-null  float64
#  20  arm_Nightlife                  15573 non-null  float64
#  21  arm_Seafood                    15573 non-null  float64
#  22  arm_Thai                       15573 non-null  float64
#  23  arm_Vietnamese                 15573 non-null  float64
#  24  Downtown Core                  15573 non-null  int64
#  25  Financial District             15573 non-null  int64
#  26  Queen Street West              15573 non-null  int64
#  27  Kensington Market              15573 non-null  int64
#  28  Wychwood                       15573 non-null  int64
#  29  Entertainment District         15573 non-null  int64
#  30  Parkdale                       15573 non-null  int64
#  31  Ryerson                        15573 non-null  int64
#  32  Distillery District            15573 non-null  int64
#  33  Liberty Village                15573 non-null  int64
#  34  stars_stddev                   15573 non-null  float64
#  35  stars_avg                      15573 non-null  float64
#  36  user_American                  15573 non-null  float64
#  37  user_Asian Fusion              15573 non-null  float64
#  38  user_Bakeries                  15573 non-null  float64
#  39  user_Bars                      15573 non-null  float64
#  40  user_Breakfast & Brunch        15573 non-null  float64
#  41  user_Chinese                   15573 non-null  float64
#  42  user_Desserts                  15573 non-null  float64
#  43  user_Italian                   15573 non-null  float64
#  44  user_Japanese                  15573 non-null  float64
#  45  user_Korean                    15573 non-null  float64
#  46  user_Mexican                   15573 non-null  float64
#  47  user_Nightlife                 15573 non-null  float64
#  48  user_Seafood                   15573 non-null  float64
#  49  user_Thai                      15573 non-null  float64
#  50  user_Vietnamese                15573 non-null  float64
#  51  user_American_ratio            15573 non-null  float64
#  52  user_Asian Fusion_ratio        15573 non-null  float64
#  53  user_Bakeries_ratio            15573 non-null  float64
#  54  user_Bars_ratio                15573 non-null  float64
#  55  user_Breakfast & Brunch_ratio  15573 non-null  float64
#  56  user_Chinese_ratio             15573 non-null  float64
#  57  user_Desserts_ratio            15573 non-null  float64
#  58  user_Italian_ratio             15573 non-null  float64
#  59  user_Japanese_ratio            15573 non-null  float64
#  60  user_Korean_ratio              15573 non-null  float64
#  61  user_Mexican_ratio             15573 non-null  float64
#  62  user_Nightlife_ratio           15573 non-null  float64
#  63  user_Seafood_ratio             15573 non-null  float64
#  64  user_Thai_ratio                15573 non-null  float64
#  65  user_Vietnamese_ratio          15573 non-null  float64
# dtypes: float64(47), int64(12), object(7)
# memory usage: 7.8+ MB

# %%
len(data.business_id.unique())
# Out:
# 23

# %%
88000/15572
# Out:
# 5.651168764449011

# %%
data_sample = data.sample(n = 88000, random_state = 1, replace = True)

# %%
data_sample
# Out:
#        Unnamed: 0               review_id                 user_id  \
# 13349       13349  iPw4I5ZV1bIhuKnquiTPog  r2NwCJjHof3_SINoQtHLpA
# 235           235  sEfrLtLovGp_FhKVQR8oFQ  TZelLnaGbHgaG7LBI6rfgg
# 12172       12172  _yKHQB8-vL_a1Sd482eCUw  z7vFhuTstnUBpn1GGThJqQ
# 5192         5192  u0qFPXP8D3yxtc5sq031sA  87-KPVeEqoMpPez8d26jKg
# 905           905  iaoe_YRPGqo_F0evyRMGtg  FREeRQtjdJU83AFtdETBBw
# ...           ...                     ...                     ...
# 4577         4577  OIxTm1P4VxFdtPJbN5K6Lw  _QTxuH-DeQ8FfzLuiKXJsA
# 10196       10196  RwqhSXcWkDZN9dVGU9m1wQ  OZWskTOKCWvYejhu63gFmQ
# 6036         6036  lf9My_o4n-jFwPAe344xsA  kXbAAUA7RehortO6zB7Lwg
# 3078         3078  xLdILTdK5nUKoTEY7wAnqw  WWnhqRnWWjutMqh-2SzEuQ
# 9540         9540  25m_YhU8HoC1FruJakjJbg  Du_IfiiJLU0ReeRetapkzA
#
#                   business_id  stars        date  \
# 13349  kOFDVcnj-8fd3doIpCQ06A      0  2014-05-01
# 235    kOFDVcnj-8fd3doIpCQ06A      1  2010-06-12
# 12172  k6zmSLmYAquCpJGKNnTgSQ      1  2015-09-21
# 5192   N93EYZy9R0sdlEvubu94ig      1  2016-06-13
# 905    aLcFhMe6DDJ430zelCpd2A      1  2015-09-03
# ...                       ...    ...         ...
# 4577   N93EYZy9R0sdlEvubu94ig      1  2014-09-10
# 10196  Yl2TN9c23ZGLUBSD9ks5Uw      1  2015-01-29
# 6036   e41TP5cXZqSrz50xCBJqZw      1  2014-05-23
# 3078   a8pmtlVKf7NiSLI-4KejIw      1  2017-10-20
# 9540   RwRNR4z3kY-4OsFqigY5sw      0  2015-04-18
#
#                                                     text  \
# 13349  GROSS.  I read reviews of people raving about ...
# 235    They really keep pushing it up...I'm almost wi...
# 12172  Had the four pc chicken waffle and smoked trou...
# 5192   Love Banh Mi Boys! Great switch up from the av...
# 905    The last experience here when we came out was ...
# ...                                                  ...
# 4577   YES. AWESOME. TASTY.\n\nI ordered the grilled ...
# 10196  A delicious and impressive representation of t...
# 6036   Had been here for brunch before but after eyei...
# 3078   I visited Toronto for the first time last week...
# 9540   This cheesecake is overrated. NY cheesecake ha...
#
#                                       name                     address  \
# 13349           "Mildred's Temple Kitchen"           "85 Hanna Avenue"
# 235             "Mildred's Temple Kitchen"           "85 Hanna Avenue"
# 12172                     "The Stockyards"  "699 Saint Clair Avenue W"
# 5192                        "Banh Mi Boys"        "392 Queen Street W"
# 905                        "Khao San Road"           "11 Charlotte St"
# ...                                    ...                         ...
# 4577                        "Banh Mi Boys"        "392 Queen Street W"
# 10196                             "Byblos"          "11 Duncan Street"
# 6036        "Insomnia Restaurant & Lounge"        "563 Bloor Street W"
# 3078                "El Catrin Destileria"        "18 Tank House Lane"
# 9540   "Uncle Tetsu's Japanese Cheesecake"            "598 Bay Street"
#
#        arm_American  ...  user_Desserts_ratio  user_Italian_ratio  \
# 13349           1.0  ...                 0.00            0.000000
# 235             1.0  ...                 0.00            0.000000
# 12172           1.0  ...                 0.00            0.000000
# 5192            0.0  ...                 0.00            0.142857
# 905             0.0  ...                 0.00            0.076923
# ...             ...  ...                  ...                 ...
# 4577            0.0  ...                 0.00            0.000000
# 10196           0.0  ...                 0.00            0.000000
# 6036            0.0  ...                 0.00            0.000000
# 3078            0.0  ...                 0.00            0.000000
# 9540            0.0  ...                 0.25            0.000000
#
#        user_Japanese_ratio  user_Korean_ratio  user_Mexican_ratio  \
# 13349             0.000000           0.000000            0.000000
# 235               0.285714           0.142857            0.142857
# 12172             0.000000           0.000000            0.000000
# 5192              0.000000           0.000000            0.142857
# 905               0.230769           0.076923            0.153846
# ...                    ...                ...                 ...
# 4577              0.000000           0.000000            0.000000
# 10196             0.000000           0.000000            0.200000
# 6036              0.000000           0.000000            0.500000
# 3078              0.500000           0.500000            0.500000
# 9540              0.500000           0.000000            0.000000
#
#        user_Nightlife_ratio  user_Seafood_ratio  user_Thai_ratio  \
# 13349              0.000000            0.000000         0.000000
# 235                0.428571            0.000000         0.142857
# 12172              0.000000            0.000000         0.000000
# 5192               0.285714            0.000000         0.142857
# 905                0.384615            0.076923         0.076923
# ...                     ...                 ...              ...
# 4577               0.000000            0.000000         0.000000
# 10196              0.000000            0.000000         0.400000
# 6036               1.000000            0.000000         0.000000
# 3078               0.000000            0.000000         0.000000
# 9540               0.000000            0.000000         0.250000
#
#        user_Vietnamese_ratio  arm_id
# 13349               0.000000       0
# 235                 0.000000       0
# 12172               0.000000       1
# 5192                0.142857       2
# 905                 0.076923       3
# ...                      ...     ...
# 4577                1.000000       2
# 10196               0.000000      16
# 6036                0.000000      15
# 3078                0.000000      20
# 9540                0.000000      21
#
# [88000 rows x 67 columns]

# %%
algos = [
    EpsilonGreedy(epsilon=0.1)
    , EpsilonGreedy(epsilon=0.3)
    , EpsilonDecay()
    , Softmax(tau=0.1)
    , Softmax(tau=0.3)
    , AnnealingSoftmax()
    , UCB()
    , BayesianUCB()
    , ThompsonSampling()
    , LinUCB()
    , LinUCB(alpha=0.3)
    , ContextualThompsonSampling()
    , ContextualThompsonSampling(delta=0.1, epsilon=0.1)
]

results4 = evaluation_replay(algos, data_sample, arm_features + ratio_features + neighborhood_cols + user_cols)
# Out:
# Running EpsilonGreedy with epsilon=0.1: 100%|██████████| 88000/88000 [00:18<00:00, 4709.41it/s]
# Running EpsilonGreedy with epsilon=0.3: 100%|██████████| 88000/88000 [00:18<00:00, 4758.93it/s]
# Running EpsilonDecay: 100%|██████████| 88000/88000 [00:20<00:00, 4399.64it/s]
# Running Softmax with temperature=0.1: 100%|██████████| 88000/88000 [00:23<00:00, 3728.22it/s]
# Running Softmax with temperature=0.3: 100%|██████████| 88000/88000 [00:23<00:00, 3780.73it/s]
# Running AnnealingSoftmax: 100%|██████████| 88000/88000 [00:23<00:00, 3698.40it/s]
# Running UCB: 100%|██████████| 88000/88000 [00:22<00:00, 3833.96it/s]
# Running BayesianUCB with stdnum=3.0: 100%|██████████| 88000/88000 [00:26<00:00, 3375.04it/s]
# Running ThompsonSampling: 100%|██████████| 88000/88000 [00:21<00:00, 4186.33it/s]
# Running LinUCB with alpha=0.1: 100%|██████████| 88000/88000 [38:56<00:00, 37.66it/s]
# Running LinUCB with alpha=0.3: 100%|██████████| 88000/88000 [33:20<00:00, 43.98it/s]
# Running ContextualThompsonSampling with delta=0.5, epsilon=0.5, R=0.01: 100%|██████████| 88000/88000 [1:02:27<00:00, 23.48it/s]
# Running ContextualThompsonSampling with delta=0.1, epsilon=0.1, R=0.01: 100%|██████████| 88000/88000 [8:25:07<00:00,  2.90it/s]

# %%
results4.to_csv('results_toronto_with_params_sampled.csv')

# %%
present_results(results4, 'cumulative_reward')

# %%
present_results(results4[results4['average_reward'] < 0.1], 'average_reward')
